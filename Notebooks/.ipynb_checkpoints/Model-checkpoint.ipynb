# %%
# Import statements for machine learning libraries and image classification
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from pathlib import Path
from sklearn.metrics import classification_report
from sklearn.utils import class_weight

# %%
# Get file directory of images
data_dir = Path('../Images/chest_xray/All')

# %%
# Print total number of images
image_count = len(list(data_dir.glob('*/*.jpeg')))
print(image_count)
# Out:
# 5856

# %%
# Show Normal Lungs
normal_lungs = list(data_dir.glob('NORMAL/*'))
PIL.Image.open(str(normal_lungs[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1857x1317 at 0x2555F90FD48>

# %%
# Show Pneumonia Lungs
pneumonia_lungs = list(data_dir.glob('PNEUMONIA/*'))
PIL.Image.open(str(pneumonia_lungs[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1152x760 at 0x2555FB39F88>

# %%
# Define image model parameters
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ## Load Image Training/Testing Data

# %%
# Preprocess Training Data
# Automatically labels image data based on file directories
# Note: Shuffle = True randomizes image sets each time the variable is called

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  shuffle=True)
# Out:
# Found 5856 files belonging to 2 classes.
# Using 4685 files for training.

# %%
# Preprocess Testing Data
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  shuffle=True)
# Out:
# Found 5856 files belonging to 2 classes.
# Using 1171 files for validation.

# %%
# Show different outcomes
class_names = train_ds.class_names
print(class_names)
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
# Show sample of 9 images
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
# For context of LEARNING this is the shape of the objects
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
    
'''The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.

You can call .numpy() on the image_batch and labels_batch tensors to convert them to a numpy.ndarray'''
# Out:
# (32, 180, 180, 3)
# (32,)
# 'The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.\n\nYou can call .numpy() on the image_batch and labels_batch tensors to convert them to a numpy.ndarray'

# %%
# For context of LEARNING this is how you would use rescaled or normalized data layer based on image sizes
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# ## Simple Model Creation

# %%
# Creating a model
# In this model the image data is rescaled and then processed through 3 layers
num_classes = 2

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Compile the model showing the accuracy metrics
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_4 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 3,988,898
# Trainable params: 3,988,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Calculate class weights to balance problem as the dataset is inbalanced with too many pneumonia cases
y_test = np.concatenate([y for x, y in val_ds], axis=0)
class_weights = class_weight.compute_class_weight('balanced',classes=np.unique(y_test),y=y_test)

weight_for_0 = class_weights[0]
weight_for_1 = class_weights[1]

# Use class weights to balance model inputs
class_weights = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 2.03
# Weight for class 1: 0.66

# %%
# Traing a simple model
epochs=5
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  class_weight=class_weights
)
# Out:
# Epoch 1/5
# 147/147 [==============================] - 82s 558ms/step - loss: 0.3237 - accuracy: 0.8534 - val_loss: 0.1494 - val_accuracy: 0.9411
# Epoch 2/5
# 147/147 [==============================] - 82s 557ms/step - loss: 0.1709 - accuracy: 0.9334 - val_loss: 0.1542 - val_accuracy: 0.9436
# Epoch 3/5
# 147/147 [==============================] - 82s 555ms/step - loss: 0.1485 - accuracy: 0.9422 - val_loss: 0.1389 - val_accuracy: 0.9513
# Epoch 4/5
# 147/147 [==============================] - 82s 555ms/step - loss: 0.1262 - accuracy: 0.9507 - val_loss: 0.2146 - val_accuracy: 0.9317
# Epoch 5/5
# 147/147 [==============================] - 81s 554ms/step - loss: 0.1057 - accuracy: 0.9584 - val_loss: 0.1549 - val_accuracy: 0.9462

# %%
# Visualize the model using the history variable which has the accuracy metrics
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# Set the range based on the number of epochs
epochs_range = range(epochs)

# Plot a figure showing accuracy on training and testing datasets
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Plot a figure showing loss on training and testing dataset
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Saving the Model
model_name = 'basic_model-1-20-21'
model_path = Path(f'../Models/{model_name}')

model.save(model_path)
# Out:
# INFO:tensorflow:Assets written to: ..\Models\basic_model-1-20-21\assets

# %%
# Overfitting Advice
'''In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of overfitting.

When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.

There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use data augmentation and add Dropout to your model.'''
# Out:
# "In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of overfitting.\n\nWhen there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.\n\nThere are multiple ways to fight overfitting in the training process. In this tutorial, you'll use data augmentation and add Dropout to your model."

# %%
# Use data augmentation to help with overfitting
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width,3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1)
  ]
)

# %%
# Show what data augmentation is
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ## Create A Better Model

# %%
# Create a model that addresses overfitting which is common in image classification
# Use data_augmentation to generalize the model by flipping, rotating, and changing the images
# Use a dropout layer to randomly drop out nodes during training reducing overfitting
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Compile the model again
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Model summary 2.0
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_4 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_5 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 3,988,898
# Trainable params: 3,988,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Retrain improved model with many more epochs
epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  class_weight=class_weights
)
# Out:
# Epoch 1/100
# 147/147 [==============================] - 102s 693ms/step - loss: 0.5548 - accuracy: 0.6619 - val_loss: 1.6525 - val_accuracy: 0.3775
# Epoch 2/100
# 147/147 [==============================] - 94s 637ms/step - loss: 0.3401 - accuracy: 0.8508 - val_loss: 0.2637 - val_accuracy: 0.8941
# Epoch 3/100
# 147/147 [==============================] - 91s 619ms/step - loss: 0.3187 - accuracy: 0.8604 - val_loss: 0.2768 - val_accuracy: 0.8847
# Epoch 4/100
# 147/147 [==============================] - 91s 620ms/step - loss: 0.2583 - accuracy: 0.8918 - val_loss: 0.4125 - val_accuracy: 0.8480
# Epoch 5/100
# 147/147 [==============================] - 91s 618ms/step - loss: 0.2316 - accuracy: 0.9025 - val_loss: 0.2971 - val_accuracy: 0.8873
# Epoch 6/100
# 147/147 [==============================] - 91s 621ms/step - loss: 0.2366 - accuracy: 0.9027 - val_loss: 0.3145 - val_accuracy: 0.8822
# Epoch 7/100
# 147/147 [==============================] - 91s 620ms/step - loss: 0.2240 - accuracy: 0.9106 - val_loss: 0.2225 - val_accuracy: 0.9180
# Epoch 8/100
# 147/147 [==============================] - 91s 618ms/step - loss: 0.2121 - accuracy: 0.9140 - val_loss: 0.3551 - val_accuracy: 0.8711
# Epoch 9/100
# 147/147 [==============================] - 91s 619ms/step - loss: 0.2082 - accuracy: 0.9104 - val_loss: 0.2347 - val_accuracy: 0.9044
# Epoch 10/100
# 147/147 [==============================] - 91s 622ms/step - loss: 0.2222 - accuracy: 0.9099 - val_loss: 0.3851 - val_accuracy: 0.8488
# Epoch 11/100
# 147/147 [==============================] - 91s 618ms/step - loss: 0.1877 - accuracy: 0.9259 - val_loss: 0.3995 - val_accuracy: 0.8540
# Epoch 12/100
# 147/147 [==============================] - 91s 616ms/step - loss: 0.2019 - accuracy: 0.9187 - val_loss: 0.2594 - val_accuracy: 0.8984
# Epoch 13/100
# 147/147 [==============================] - 91s 618ms/step - loss: 0.1999 - accuracy: 0.9232 - val_loss: 0.2432 - val_accuracy: 0.9035
# Epoch 14/100
# 147/147 [==============================] - 91s 616ms/step - loss: 0.1896 - accuracy: 0.9229 - val_loss: 0.1739 - val_accuracy: 0.9317
# Epoch 15/100
# 147/147 [==============================] - 91s 617ms/step - loss: 0.1870 - accuracy: 0.9249 - val_loss: 0.2273 - val_accuracy: 0.9137
# Epoch 16/100
# 147/147 [==============================] - 91s 618ms/step - loss: 0.1910 - accuracy: 0.9287 - val_loss: 0.1373 - val_accuracy: 0.9530
# Epoch 17/100
# 147/147 [==============================] - 91s 617ms/step - loss: 0.1847 - accuracy: 0.9251 - val_loss: 0.2122 - val_accuracy: 0.9206
# Epoch 18/100
# 147/147 [==============================] - 91s 621ms/step - loss: 0.1863 - accuracy: 0.9291 - val_loss: 0.3975 - val_accuracy: 0.8488
# Epoch 19/100
# 147/147 [==============================] - 102s 695ms/step - loss: 0.1787 - accuracy: 0.9272 - val_loss: 0.1753 - val_accuracy: 0.9342
# Epoch 20/100
# 147/147 [==============================] - 106s 718ms/step - loss: 0.1784 - accuracy: 0.9311 - val_loss: 0.1594 - val_accuracy: 0.9402
# Epoch 21/100
# 147/147 [==============================] - 107s 726ms/step - loss: 0.1715 - accuracy: 0.9347 - val_loss: 0.1681 - val_accuracy: 0.9368
# Epoch 22/100
# 147/147 [==============================] - 105s 715ms/step - loss: 0.1665 - accuracy: 0.9372 - val_loss: 0.1596 - val_accuracy: 0.9385
# Epoch 23/100
# 147/147 [==============================] - 109s 738ms/step - loss: 0.1607 - accuracy: 0.9379 - val_loss: 0.1285 - val_accuracy: 0.9505
# Epoch 24/100
# 147/147 [==============================] - 104s 704ms/step - loss: 0.1560 - accuracy: 0.9394 - val_loss: 0.2478 - val_accuracy: 0.9103
# Epoch 25/100
# 147/147 [==============================] - 107s 725ms/step - loss: 0.1637 - accuracy: 0.9362 - val_loss: 0.1925 - val_accuracy: 0.9283
# Epoch 26/100
# 147/147 [==============================] - 107s 725ms/step - loss: 0.1637 - accuracy: 0.9387 - val_loss: 0.1695 - val_accuracy: 0.9411
# Epoch 27/100
# 147/147 [==============================] - 104s 708ms/step - loss: 0.1616 - accuracy: 0.9390 - val_loss: 0.1785 - val_accuracy: 0.9402
# Epoch 28/100
# 147/147 [==============================] - 108s 735ms/step - loss: 0.1571 - accuracy: 0.9368 - val_loss: 0.1856 - val_accuracy: 0.9368
# Epoch 29/100
# 147/147 [==============================] - 105s 716ms/step - loss: 0.1454 - accuracy: 0.9422 - val_loss: 0.1386 - val_accuracy: 0.9530
# Epoch 30/100
# 147/147 [==============================] - 103s 698ms/step - loss: 0.1463 - accuracy: 0.9432 - val_loss: 0.1908 - val_accuracy: 0.9360
# Epoch 31/100
# 147/147 [==============================] - 105s 715ms/step - loss: 0.1435 - accuracy: 0.9477 - val_loss: 0.1415 - val_accuracy: 0.9496
# Epoch 32/100
# 147/147 [==============================] - 104s 707ms/step - loss: 0.1476 - accuracy: 0.9456 - val_loss: 0.1348 - val_accuracy: 0.9522
# Epoch 33/100
# 147/147 [==============================] - 104s 706ms/step - loss: 0.1602 - accuracy: 0.9392 - val_loss: 0.3113 - val_accuracy: 0.8950
# Epoch 34/100
# 147/147 [==============================] - 105s 714ms/step - loss: 0.1598 - accuracy: 0.9372 - val_loss: 0.1555 - val_accuracy: 0.9453
# Epoch 35/100
# 147/147 [==============================] - 106s 723ms/step - loss: 0.1442 - accuracy: 0.9424 - val_loss: 0.1726 - val_accuracy: 0.9402
# Epoch 36/100
# 147/147 [==============================] - 104s 708ms/step - loss: 0.1427 - accuracy: 0.9469 - val_loss: 0.1397 - val_accuracy: 0.9513
# Epoch 37/100
# 147/147 [==============================] - 106s 721ms/step - loss: 0.1367 - accuracy: 0.9469 - val_loss: 0.2309 - val_accuracy: 0.9206
# Epoch 38/100
# 147/147 [==============================] - 105s 711ms/step - loss: 0.1465 - accuracy: 0.9503 - val_loss: 0.1268 - val_accuracy: 0.9582
# Epoch 39/100
# 147/147 [==============================] - 104s 710ms/step - loss: 0.1359 - accuracy: 0.9445 - val_loss: 0.1064 - val_accuracy: 0.9590
# Epoch 40/100
# 147/147 [==============================] - 106s 720ms/step - loss: 0.1433 - accuracy: 0.9451 - val_loss: 0.2288 - val_accuracy: 0.9172
# Epoch 41/100
# 147/147 [==============================] - 106s 722ms/step - loss: 0.1505 - accuracy: 0.9439 - val_loss: 0.1437 - val_accuracy: 0.9505
# Epoch 42/100
# 147/147 [==============================] - 105s 712ms/step - loss: 0.1324 - accuracy: 0.9492 - val_loss: 0.1731 - val_accuracy: 0.9377
# Epoch 43/100
# 147/147 [==============================] - 105s 711ms/step - loss: 0.1265 - accuracy: 0.9537 - val_loss: 0.1108 - val_accuracy: 0.9624
# Epoch 44/100
# 147/147 [==============================] - 99s 675ms/step - loss: 0.1323 - accuracy: 0.9492 - val_loss: 0.1082 - val_accuracy: 0.9624
# Epoch 45/100
# 147/147 [==============================] - 103s 704ms/step - loss: 0.1400 - accuracy: 0.9471 - val_loss: 0.1390 - val_accuracy: 0.9513
# Epoch 46/100
# 147/147 [==============================] - 104s 704ms/step - loss: 0.1274 - accuracy: 0.9515 - val_loss: 0.1666 - val_accuracy: 0.9419
# Epoch 47/100
# 147/147 [==============================] - 104s 704ms/step - loss: 0.1252 - accuracy: 0.9509 - val_loss: 0.2066 - val_accuracy: 0.9223
# Epoch 48/100
# 147/147 [==============================] - 104s 710ms/step - loss: 0.1348 - accuracy: 0.9503 - val_loss: 0.1288 - val_accuracy: 0.9505
# Epoch 49/100
# 147/147 [==============================] - 103s 699ms/step - loss: 0.1256 - accuracy: 0.9535 - val_loss: 0.1200 - val_accuracy: 0.9590
# Epoch 50/100
# 147/147 [==============================] - 107s 726ms/step - loss: 0.1298 - accuracy: 0.9501 - val_loss: 0.1051 - val_accuracy: 0.9641
# Epoch 51/100
# 147/147 [==============================] - 104s 706ms/step - loss: 0.1262 - accuracy: 0.9511 - val_loss: 0.1735 - val_accuracy: 0.9402
# Epoch 52/100
# 147/147 [==============================] - 105s 711ms/step - loss: 0.1244 - accuracy: 0.9524 - val_loss: 0.1251 - val_accuracy: 0.9564
# Epoch 53/100
# 147/147 [==============================] - 107s 729ms/step - loss: 0.1144 - accuracy: 0.9545 - val_loss: 0.1686 - val_accuracy: 0.9351
# Epoch 54/100
# 147/147 [==============================] - 108s 733ms/step - loss: 0.1158 - accuracy: 0.9541 - val_loss: 0.1566 - val_accuracy: 0.9462
# Epoch 55/100
# 147/147 [==============================] - 105s 717ms/step - loss: 0.1285 - accuracy: 0.9526 - val_loss: 0.1677 - val_accuracy: 0.9411
# Epoch 56/100
# 147/147 [==============================] - 103s 703ms/step - loss: 0.1178 - accuracy: 0.9541 - val_loss: 0.1526 - val_accuracy: 0.9496
# Epoch 57/100
# 147/147 [==============================] - 108s 732ms/step - loss: 0.1199 - accuracy: 0.9571 - val_loss: 0.1833 - val_accuracy: 0.9334
# Epoch 58/100
# 147/147 [==============================] - 108s 736ms/step - loss: 0.1143 - accuracy: 0.9571 - val_loss: 0.1436 - val_accuracy: 0.9488
# Epoch 59/100
# 147/147 [==============================] - 105s 716ms/step - loss: 0.1073 - accuracy: 0.9577 - val_loss: 0.1981 - val_accuracy: 0.9385
# Epoch 60/100
# 147/147 [==============================] - 104s 704ms/step - loss: 0.1174 - accuracy: 0.9569 - val_loss: 0.1723 - val_accuracy: 0.9419
# Epoch 61/100
# 147/147 [==============================] - 104s 711ms/step - loss: 0.1174 - accuracy: 0.9558 - val_loss: 0.1439 - val_accuracy: 0.9453
# Epoch 62/100
# 147/147 [==============================] - 106s 722ms/step - loss: 0.1114 - accuracy: 0.9560 - val_loss: 0.1648 - val_accuracy: 0.9436
# Epoch 63/100
# 147/147 [==============================] - 104s 709ms/step - loss: 0.1132 - accuracy: 0.9565 - val_loss: 0.1050 - val_accuracy: 0.9650
# Epoch 64/100
# 147/147 [==============================] - 103s 703ms/step - loss: 0.1094 - accuracy: 0.9577 - val_loss: 0.1663 - val_accuracy: 0.9402
# Epoch 65/100
# 147/147 [==============================] - 106s 720ms/step - loss: 0.1158 - accuracy: 0.9569 - val_loss: 0.1239 - val_accuracy: 0.9624
# Epoch 66/100
# 147/147 [==============================] - 105s 712ms/step - loss: 0.1047 - accuracy: 0.9586 - val_loss: 0.1112 - val_accuracy: 0.9582
# Epoch 67/100
# 147/147 [==============================] - 107s 727ms/step - loss: 0.1146 - accuracy: 0.9584 - val_loss: 0.1441 - val_accuracy: 0.9556
# Epoch 68/100
# 147/147 [==============================] - 105s 714ms/step - loss: 0.1181 - accuracy: 0.9545 - val_loss: 0.1440 - val_accuracy: 0.9505
# Epoch 69/100
# 147/147 [==============================] - 105s 713ms/step - loss: 0.1064 - accuracy: 0.9586 - val_loss: 0.1182 - val_accuracy: 0.9547
# Epoch 70/100
# 147/147 [==============================] - 104s 705ms/step - loss: 0.0980 - accuracy: 0.9624 - val_loss: 0.1522 - val_accuracy: 0.9488
# Epoch 71/100
# 147/147 [==============================] - 106s 722ms/step - loss: 0.1034 - accuracy: 0.9601 - val_loss: 0.1123 - val_accuracy: 0.9607
# Epoch 72/100
# 147/147 [==============================] - 104s 706ms/step - loss: 0.1050 - accuracy: 0.9567 - val_loss: 0.1553 - val_accuracy: 0.9530
# Epoch 73/100
# 147/147 [==============================] - 105s 715ms/step - loss: 0.1000 - accuracy: 0.9616 - val_loss: 0.1234 - val_accuracy: 0.9599
# Epoch 74/100
# 147/147 [==============================] - 106s 721ms/step - loss: 0.1042 - accuracy: 0.9601 - val_loss: 0.2011 - val_accuracy: 0.9377
# Epoch 75/100
# 147/147 [==============================] - 104s 707ms/step - loss: 0.1028 - accuracy: 0.9597 - val_loss: 0.2338 - val_accuracy: 0.9342
# Epoch 76/100
# 147/147 [==============================] - 105s 717ms/step - loss: 0.1062 - accuracy: 0.9588 - val_loss: 0.1221 - val_accuracy: 0.9522
# Epoch 77/100
# 147/147 [==============================] - 102s 696ms/step - loss: 0.0944 - accuracy: 0.9635 - val_loss: 0.1184 - val_accuracy: 0.9616
# Epoch 78/100
# 147/147 [==============================] - 106s 722ms/step - loss: 0.1012 - accuracy: 0.9614 - val_loss: 0.1147 - val_accuracy: 0.9564
# Epoch 79/100
# 147/147 [==============================] - 107s 726ms/step - loss: 0.1010 - accuracy: 0.9639 - val_loss: 0.1629 - val_accuracy: 0.9377
# Epoch 80/100
# 147/147 [==============================] - 109s 740ms/step - loss: 0.1010 - accuracy: 0.9614 - val_loss: 0.2211 - val_accuracy: 0.9300
# Epoch 81/100
# 147/147 [==============================] - 105s 717ms/step - loss: 0.1018 - accuracy: 0.9614 - val_loss: 0.1833 - val_accuracy: 0.9394
# Epoch 82/100
# 147/147 [==============================] - 109s 740ms/step - loss: 0.0937 - accuracy: 0.9637 - val_loss: 0.1070 - val_accuracy: 0.9599
# Epoch 83/100
# 147/147 [==============================] - 108s 736ms/step - loss: 0.0994 - accuracy: 0.9631 - val_loss: 0.1279 - val_accuracy: 0.9556
# Epoch 84/100
# 147/147 [==============================] - 108s 734ms/step - loss: 0.1047 - accuracy: 0.9597 - val_loss: 0.1405 - val_accuracy: 0.9479
# Epoch 85/100
# 147/147 [==============================] - 105s 716ms/step - loss: 0.1019 - accuracy: 0.9599 - val_loss: 0.1111 - val_accuracy: 0.9599
# Epoch 86/100
# 147/147 [==============================] - 106s 723ms/step - loss: 0.0903 - accuracy: 0.9686 - val_loss: 0.1178 - val_accuracy: 0.9607
# Epoch 87/100
# 147/147 [==============================] - 108s 736ms/step - loss: 0.0989 - accuracy: 0.9635 - val_loss: 0.1633 - val_accuracy: 0.9394
# Epoch 88/100
# 147/147 [==============================] - 106s 719ms/step - loss: 0.0962 - accuracy: 0.9641 - val_loss: 0.1117 - val_accuracy: 0.9624
# Epoch 89/100
# 147/147 [==============================] - 104s 706ms/step - loss: 0.0971 - accuracy: 0.9656 - val_loss: 0.1487 - val_accuracy: 0.9445
# Epoch 90/100
# 147/147 [==============================] - 106s 718ms/step - loss: 0.0911 - accuracy: 0.9631 - val_loss: 0.1342 - val_accuracy: 0.9513
# Epoch 91/100
# 147/147 [==============================] - 104s 709ms/step - loss: 0.1055 - accuracy: 0.9573 - val_loss: 0.1782 - val_accuracy: 0.9377
# Epoch 92/100
# 147/147 [==============================] - 105s 711ms/step - loss: 0.0938 - accuracy: 0.9650 - val_loss: 0.1080 - val_accuracy: 0.9667
# Epoch 93/100
# 147/147 [==============================] - 106s 724ms/step - loss: 0.0904 - accuracy: 0.9658 - val_loss: 0.1923 - val_accuracy: 0.9325
# Epoch 94/100
# 147/147 [==============================] - 106s 721ms/step - loss: 0.0981 - accuracy: 0.9614 - val_loss: 0.1192 - val_accuracy: 0.9684
# Epoch 95/100
# 147/147 [==============================] - 108s 731ms/step - loss: 0.0935 - accuracy: 0.9639 - val_loss: 0.1281 - val_accuracy: 0.9573
# Epoch 96/100
# 147/147 [==============================] - 105s 711ms/step - loss: 0.0907 - accuracy: 0.9663 - val_loss: 0.1191 - val_accuracy: 0.9616
# Epoch 97/100
# 147/147 [==============================] - 107s 729ms/step - loss: 0.0936 - accuracy: 0.9665 - val_loss: 0.1053 - val_accuracy: 0.9752
# Epoch 98/100
# 147/147 [==============================] - 107s 731ms/step - loss: 0.0877 - accuracy: 0.9673 - val_loss: 0.1034 - val_accuracy: 0.9658
# Epoch 99/100
# 147/147 [==============================] - 108s 732ms/step - loss: 0.1024 - accuracy: 0.9629 - val_loss: 0.1457 - val_accuracy: 0.9496
# Epoch 100/100
# 147/147 [==============================] - 107s 731ms/step - loss: 0.0966 - accuracy: 0.9622 - val_loss: 0.1171 - val_accuracy: 0.9624

# %%
# Visualize the new model statistics with the same code from before
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Saving the Model
model_name = 'advanced_100_model-1-20-21'
model_path = Path(f'../Models/{model_name}')

model.save(model_path)
# Out:
# INFO:tensorflow:Assets written to: ..\Models\advanced_100_model-1-20-21\assets

# %%
# Load desired model
model_name = 'advanced_100_model-1-20-21'
model_path = Path(f'../Models/{model_name}')
model = tf.keras.models.load_model(model_path)

# %% [markdown]
# ## Analyzing Model Results

# %%
# Make predictions using test data and generate a classification report

y_pred = []
y_test = []

# Loop through testing data to make predictions paying special attention to final shapes of arrays for sklearn
for x, y in val_ds:
    y_pred = np.concatenate([y_pred,np.argmax(model.predict(x), axis=-1)])
    y_test = np.concatenate([y_test,y], axis=0)

# Print classification report from sklearn
print(classification_report(y_test, y_pred, target_names = ['NORMAL','PNEUMONIA']))
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.89      0.97      0.93       288
#    PNEUMONIA       0.99      0.96      0.97       883
#
#     accuracy                           0.96      1171
#    macro avg       0.94      0.97      0.95      1171
# weighted avg       0.96      0.96      0.96      1171

# %%
# Using a confusion matrix in tensorflow for LEARNING only as it is represented above with sklearn
tf.math.confusion_matrix(y_test, y_pred)

# %%
# Predict on the new model. A few other paths are shown for additional testing/display

# Define filepath variable
final_test_path = Path('../Images/chest_xray/val/normal/NORMAL2-IM-1430-0001.jpeg')
# final_test_path = Path('../Images/chest_xray/val/pneumonia/person1946_bacteria_4874.jpeg')
# final_test_path = Path('../Images/Predicted_Images/internet.jpg')

# Load image with keras and save to image array
img = keras.preprocessing.image.load_img(
    final_test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

# Make a prediction on the image
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

# Create a print statement that shows the result and the confidence interval
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

# Save the predicted image to a directory
img.save(f'../Images/Predicted_Images/internet - {class_names[np.argmax(score)]}.jpeg', 'JPEG')
# Out:
# This image most likely belongs to NORMAL with a 96.98 percent confidence.
